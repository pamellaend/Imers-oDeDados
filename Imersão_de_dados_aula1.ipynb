# %% [markdown]
# <a href="https://colab.research.google.com/github/pamellaend/Imers-oDeDados/blob/main/Imers%C3%A3o_de_dados_aula1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt #biblioteca para plot de graficos
import pandas as pd. # biblioteca prinicipal para dados
import seaborn as sns  #biblioteca para graficos estatisticos

url_dados = 'https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true'
# o pandas permite a leitura de dados utilizando o url

dados = pd.read_csv(url_dados, compression = 'zip') # lendo o arquivo de formato csv, dentro do url e descompacta.
dados # exibe os dados
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %%
dados.head() # mostra as 5 primeiras linhas da tabela
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
dados.shape # mostra a quantidade de linhas e colunas da tabela
# Out:
# (23814, 877)

# %%
dados['tratamento'] # exibe a coluna nomeada
# Out:
# 0           com_droga
# 1           com_droga
# 2           com_droga
# 3           com_droga
# 4           com_droga
#              ...
# 23809       com_droga
# 23810       com_droga
# 23811    com_controle
# 23812       com_droga
# 23813       com_droga
# Name: tratamento, Length: 23814, dtype: object

# %%
dados['c-0'].unique() # exibe todos os dados diferentes da coluna nomeada
# Out:
# array([-0.06  ,  0.0927, -0.1312, ...,  0.3509,  0.9538, -2.389 ])

# %%
dados['droga'].unique()
# Out:
# array(['b68db1d53', 'df89a8e5a', '18bb41b2c', ..., '573c787a2',
#        'b2fe3eca7', 'dd4a96d16'], dtype=object)

# %%
dados['tratamento'].value_counts() # Quantidade de cada tipo de tratamento
# Out:
# com_droga       21948
# com_controle     1866
# Name: tratamento, dtype: int64

# %%
dados['tratamento'].value_counts().plot.pie() #grafico em pizza da coluna tratamento

# %%
dados['dose'].value_counts() #Quantidade de D1 e D2
# Out:
# D1    12147
# D2    11667
# Name: dose, dtype: int64

# %%
dados['dose'].value_counts(normalize = True) #porcentagem da coluna dose. 51% de D1 e 48% de D2.
# Out:
# D1    0.510078
# D2    0.489922
# Name: dose, dtype: float64

# %%
dados['dose'].value_counts().plot.pie() #grafico das quantidades de D1 e D2.

# %%
dados['tempo'].value_counts() #Quantidade dos tempos
# Out:
# 48    8250
# 72    7792
# 24    7772
# Name: tempo, dtype: int64

# %%
dados['tempo'].value_counts().plot.pie() # gráfico em pizza dos tempos, pode se perceber que não é muito eficiente para analisar neste caso.

# %%
dados['tempo'].value_counts(normalize = True). # procentagem das quantidades de cada tempo utilizado
# Out:
# 48    0.346435
# 72    0.327202
# 24    0.326363
# Name: tempo, dtype: float64

# %%
dados['tempo'].value_counts().plot.bar() #grafico em barras das quantidades de cada tempo utilizado

# %%
dados_filtrados = dados[dados['g-0'] > 0] # Cria uma outra tabela apenas com os dados da coluna g0 que forem maior que 0
dados_filtrados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 6  id_001bd861f  com_droga     24   D2  ...  2.4670  0.0357  0.1351 -0.3179
# 7  id_0020d0484  com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
#
# [5 rows x 877 columns]

# %% [markdown]
# ### Desafio: Pesquisar por que a classe tratamento é tão desbalanceada?
# ### R: Há um desbalanceamento na classe tratamento por que as amostras 'com_controle' são amostras de controle, que servem como parâmetro de comparação em relação as outras amostras.

# %% [markdown]
# ###Desafio: Plot as 5 ultimas linhas da tabela.

# %%
dados.tail()
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# 23813  id_ffffdd77b     com_droga     72   D1  ... -3.5770 -0.4775 -2.1500 -4.2520
#
# [5 rows x 877 columns]

# %% [markdown]
# ###Desafio : Qual as proporções da classe "tratamento".

# %%
dados['tratamento'].value_counts(normalize = True) # procentagem da coluna tratamento. 92% com droga e 7% com controle.
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %% [markdown]
# ###Desafio: Descobrir quantas drogas diferentes foram utilizadas.

# %%
quant_drogas = dados['droga'].unique()
len(quant_drogas)
# Out:
# 3289

# %% [markdown]
# ###Desafio: query

# %%
dados.query('dose == "D2" and tempo == 48 and tratamento == "com_controle"') # O query serve para fazer um filtro dos dados
# Out:
#                  id    tratamento  tempo dose  ...     c96     c97     c98     c99
# 47     id_008a986b7  com_controle     48   D2  ... -0.4979  0.5281 -0.9245 -0.9367
# 117    id_0144e88e8  com_controle     48   D2  ...  0.1478  0.8284  0.2281  1.6320
# 163    id_01cb69424  com_controle     48   D2  ... -0.1335  0.6712 -0.4978 -0.1923
# 169    id_01df54942  com_controle     48   D2  ...  0.0758 -0.0848 -0.3605  0.5649
# 434    id_048cdfd4b  com_controle     48   D2  ... -0.2275 -0.7295  1.1720 -0.3214
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23242  id_f9abafedb  com_controle     48   D2  ...  1.0820  0.8371  0.5187 -1.0230
# 23403  id_fba51084c  com_controle     48   D2  ...  0.7585  0.6490 -0.5158  0.1767
# 23539  id_fcf7fddb9  com_controle     48   D2  ... -1.2830  0.5137  0.0737  0.8924
# 23793  id_ffd26f361  com_controle     48   D2  ...  0.8813  0.7757 -0.5272  0.7082
# ...

# %% [markdown]
# ### Desafio: Eliminar o hífen dos nomes das colunas.

# %%
dados.columns = dados.columns.str.replace('-','') # substitui nas colunas onde tiver - ele coloca espaço vazio.
dados.head() #mostra as 5 primeiras linhas da tabela
# Out:
#              id tratamento  tempo dose  ...     c96     c97     c98     c99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %% [markdown]
# ### Desafio: Deixar o gráfico mais apresentável

# %% [markdown]
# ### Método 1:

# %%
dados['tempo'].value_counts().plot.bar( title = "Amostras por Tempo(h) ", rot = 0, ylabel = 'Frequência')

# %% [markdown]
# ### Método 2:

# %%
sns.set(font_scale=1)
dados['tratamento'].value_counts().plot(kind='bar', figsize=(6, 6), rot=0) #Com relação a quantidade de cada valor diferente, plota o grafico do tipo barra, com dimensão 6x6 e com 0 graus de rotaçao nas legenda dos dados('com droga','com controle').
plt.xlabel("Tipos de tratamentos", labelpad=10)
plt.ylabel("Frequência de tratamentos", labelpad=10);

# %% [markdown]
# ###Desafio : O que foi obtido a partir desses dados até agora:
#
# Podemos perceber que existem muitas amostras (23813).
#
# Para cada ID percebemos que pode ter sido utilizado 2 tipos de tratamento, com droga ou com controle. Sendo que o mais utilizado foi o tratamento com drogas.
#
# Foram utilizados 3 tempos distintos 24h, 48h ou 72h, cada amostra foi utilizado um. Sendo que o mais utilizado foi o de 48h.
#
# Existem 2 tipos de doses. Sendo a mais utilizada foi a D1.
